# %%
import pandas as pd

# %%
port_without_hmm = pd.read_pickle("port_without.pkl")
port_with_hmm = pd.read_pickle("port_with.pkl")

# %%
port_without_hmm
# Out:
#            Invested Amount  Final Amount Number of Trades           PnL  \
# HDFCBANK             10000   10560.77899               12     560.77899
# ICICIBANK            10000   9989.614016               18    -10.385984
# KOTAKBANK            10000    10308.6009               20      308.6009
# ONGC                 10000   9198.240765               20   -801.759235
# INFY                 10000    9718.72285               16    -281.27715
# RELIANCE             10000  11642.677855               12   1642.677855
# HDFC                 10000   10256.49715               16     256.49715
# LT                   10000   9766.627696               18   -233.372304
# IOC                  10000   8794.833325               22  -1205.166675
# SBIN                 10000   10440.14991               18     440.14991
# HINDUNILVR           10000  10645.769665               18    645.769665
# MARUTI               10000   10306.55655               14     306.55655
# ...

# %%
port_with_hmm
# Out:
#            Invested Amount  Final Amount Number of Trades          PnL  \
# HDFCBANK             10000   10539.82183               40    539.82183
# ICICIBANK            10000   9987.842031               28   -12.157969
# KOTAKBANK            10000   10153.75595               54    153.75595
# ONGC                 10000   9226.209245               94  -773.790755
# INFY                 10000     9814.2199               70    -185.7801
# RELIANCE             10000  11523.737215               24  1523.737215
# HDFC                 10000    10058.3863               28      58.3863
# LT                   10000   9990.057544               24    -9.942456
# IOC                  10000     8779.5593               30   -1220.4407
# SBIN                 10000     9939.5073               26     -60.4927
# HINDUNILVR           10000  10457.693785               78   457.693785
# MARUTI               10000  10307.042875               36   307.042875
# ...
